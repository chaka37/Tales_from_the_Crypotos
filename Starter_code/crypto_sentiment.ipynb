# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from newsapi import NewsApiClient
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ldkel\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable

news_api_key = "5311671e6a8941878360f7a695b22582"

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy")
btc_articles
# Out:
# {'status': 'ok',
#  'totalResults': 9407,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'New York passes a bill to limit bitcoin mining',
#    'description': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of Governor Kathy Hochul, who will sign it into law or veto th…",
#    'url': 'https://www.engadget.com/new-york-cryptocurrency-bill-bitcoin-mining-climate-change-161126292.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/a8217250-bdfa-11eb-bfc4-2663225cea83',
#    'publishedAt': '2022-06-03T16:11:26Z',
#    'content': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Passant Rabie',
#    'title': 'Jay-Z and Jack Dorsey Launch Bitcoin Academy for New Generation of Crypto Bros',
#    'description': 'Rapper and entrepreneur Shawn Carter, better known as Jay-Z, is bringing Bitcoin to the place where he grew up. On Thursday, Jay-Z and former Twitter CEO Jack Dorsey announced the launch of Bitcoin Academy, which will offer free classes on cryptocurrency for …',
#    'url': 'https://gizmodo.com/jay-z-jack-dorsey-bitcoin-academy-1849040407',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/48fbb5e09973afbe730474c5cb0aadd4.jpg',
#    'publishedAt': '2022-06-09T19:45:00Z',
#    'content': 'Rapper and entrepreneur Shawn Carter, better known as Jay-Z, is bringing Bitcoin to the place where he grew up. On Thursday, Jay-Z and former Twitter CEO Jack Dorsey announced the launch of Bitcoin A… [+2920 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lucas Ropek',
#    'title': "Bitcoin Wasn't as Decentralized or Anonymous as Crypto Bros Told You, Study Finds",
#    'description': 'A new study on bitcoin calls into question whether the digital currency is truly as decentralized and anonymous as its biggest devotees would have you believe. Read more...',
#    'url': 'https://gizmodo.com/bitcoin-cryptocurrency-centralized-not-anonymous-study-1849029656',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/d3390dc22b7788490c85b7ec69134874.jpg',
#    'publishedAt': '2022-06-08T11:00:00Z',
#    'content': 'A new study on bitcoin calls into question whether the digital currency is truly as decentralized and anonymous as its biggest devotees would have you believe. \r\n Researchers from Baylor, Rice, and t… [+7343 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Why the Central African Republic adopted Bitcoin',
#    'description': 'Some 90% of people in the Central African Republic lack access to the internet, needed to use Bitcoin.',
#    'url': 'https://www.bbc.co.uk/news/world-africa-61565485',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/394F/production/_125017641_gettyimages-1320532557.jpg',
#    'publishedAt': '2022-06-05T23:03:49Z',
#    'content': "Image caption, President Faustin-Archange Touadéra wants to rethink his country's economic philosophy\r\nThe Central African Republic's decision to adopt Bitcoin as legal tender came as a surprise to m… [+8881 chars]"},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'Chipotle now accepts cryptocurrency payments',
#    'description': "You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges first. Flexa has announced that the Mexican fast food chain can now accept…",
#    'url': 'https://www.engadget.com/chipotle-accepts-cryptocurrency-payments-123013632.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-images/2019-11/62e01e20-0493-11ea-bffd-0d62f5b23b7c',
#    'publishedAt': '2022-06-02T12:30:13Z',
#    'content': "You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges first. Flexa h… [+1428 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'El Salvador: The country where you can buy anything with Bitcoin',
#    'description': 'The cryptocurrency crash is hurting many investors, including one country that has bet big on Bitcoin.',
#    'url': 'https://www.bbc.co.uk/news/technology-61813845',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/EB8F/production/_125430306_977646d4-a885-485f-b124-4aceaa1a4b98.jpg',
#    'publishedAt': '2022-06-16T01:15:20Z',
#    'content': 'By Joe TidyCyber reporter \r\nCryptocurrencies have continued to tumble this week with billions wiped from the value of tokens like Bitcoin. The crash is affecting investors worldwide, including the go… [+6815 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Philip Wang and Tara Subramaniam, CNN',
#    'title': "El Salvador's Bitcoin investment suffers amid crypto meltdown",
#    'description': 'El Salvador has embraced Bitcoin like no other country, with the government purchasing hundreds of coins last year as it announced that the cryptocurrency would become legal tender.',
#    'url': 'https://www.cnn.com/2022/06/14/americas/el-salvador-bitcoin-losses-intl-latam/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220522194357-salvadorenos-bitcoin-confianza-devaluacion-merlin-delcid-mirador-mundial-cnn-pkg-00022610-super-tease.png',
#    'publishedAt': '2022-06-15T00:38:11Z',
#    'content': '(CNN)El Salvador has embraced Bitcoin like no other country, with the government purchasing hundreds of coins last year as it announced that the cryptocurrency would become legal tender. \r\nBut as the… [+842 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'Luna Foundation Tried to Prop Up Terra’s Crumbling Base With Billions in Bitcoin, But It Still Failed',
#    'description': 'As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that went. In a similar vein, Terra blockchain reportedly spent $…',
#    'url': 'https://gizmodo.com/luna-foundation-terra-bitcoin-crypto-lfg-1848933191',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f8f25ce9a57b3454932cdead4c3278b6.jpg',
#    'publishedAt': '2022-05-16T20:45:00Z',
#    'content': 'As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Chipotle Lovers Can Now Buy Burritos With Bitcoin, Ether, and More: Report',
#    'description': 'Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to trade publication Restaurant Business. But there’s just one i…',
#    'url': 'https://gizmodo.com/chipotle-bitcoin-ethereum-dogecoin-crypto-burritos-paym-1849006239',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/a06df2b7927727af38b388d72e721dce.jpg',
#    'publishedAt': '2022-06-02T10:00:00Z',
#    'content': 'Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Richard Lawler',
#    'title': 'DeFi lending giant Celsius halts withdrawals',
#    'description': 'Celsius is a decentralized finance platform that’s one of the largest crypto lenders. It announced a “pause” on withdrawals as markets opened in Asia, leaving investors in the dark about what will happen next.',
#    'url': 'https://www.theverge.com/2022/6/13/23165401/defi-cryptocurrency-celsius-network-pause-withdrawals',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/rtDU7dALLjxGLs-7_Xbon075OgY=/0x358:5000x2976/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23623361/1239951757.jpg',
#    'publishedAt': '2022-06-13T05:09:57Z',
#    'content': 'Celsius has not said what it plans to do next\r\nExhibition And Experience Zones at The Paris NFT Day Conference\r\nThe Celsius Network, a decentralized finance (DeFi) platform and one of the largest cry… [+3737 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nilay Patel',
#    'title': 'How Ukraine’s wide use of cryptocurrency is playing out during the war',
#    'description': 'Michael Chobanian, the president of the Blockchain Association of Ukraine, discusses how cryptocurrency and blockchain could reshape the Ukrainian government.',
#    'url': 'https://www.theverge.com/23138465/decoder-ukraine-war-cryptocurrency-michael-chobanian-interview-bitcoin-usdt',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/hyxIGAl42Cl6sDQJzy2cD3X4tEg=/0x148:2050x1221/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23583410/VRG_ILLO_Decoder_Michael_Chobanian.jpg',
#    'publishedAt': '2022-05-24T15:23:59Z',
#    'content': 'Photo Illustration by Grayson Blackmon / The Verge; Photo by Oliyarnyk / CC-BY-SA-4.0\r\n\n \n\n\n With Michael Chobanian, the president of the Blockchain Association of Ukraine The terrible, unprovoked wa… [+52103 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin gains over 5% to $31441.76 - Reuters',
#    'description': 'Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-gains-over-5-3144176-2022-06-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/lEay-or8c9TPjZOEmIjrJf3ylQk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3RKTTS2CRVM2BEEDCB2ZIPV3L4.jpg',
#    'publishedAt': '2022-06-06T20:11:00Z',
#    'content': "June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world's biggest and best-known cryptocurrency is down 34.8% from the year's high… [+335 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 12.1% to $23366 - Reuters',
#    'description': 'Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-falls-121-23366-2022-06-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/2xcvLrlBIq1EK8-72AwbhUzHdkM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/NOU4XZOJJNNOHH57DRGF5PAQSM.jpg',
#    'publishedAt': '2022-06-13T20:38:00Z',
#    'content': "June 13 (Reuters) - Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 51.6% from t… [+357 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Bitcoin nears MicroStrategy 'margin call' price - Reuters",
#    'description': 'Bitcoin neared a price level on Tuesday that could force software firm MicroStrategy Inc <a href="https://www.reuters.com/companies/MSTR.O" target="_blank">(MSTR.O)</a> to stake more tokens against a bitcoin-backed loan or trigger selling of some of its vast …',
#    'url': 'https://www.reuters.com/technology/bitcoin-nears-microstrategy-margin-call-price-2022-06-14/',
#    'urlToImage': 'https://www.reuters.com/resizer/17fnKz9EKrcWPGwYCV7IBbgXL2c=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LNZQHA2RYRIOLKXNM46SZUVQ4A.jpg',
#    'publishedAt': '2022-06-14T08:02:00Z',
#    'content': 'SINGAPORE, June 14 (Reuters) - Bitcoin neared a price level on Tuesday that could force software firm MicroStrategy Inc (MSTR.O) to stake more tokens against a bitcoin-backed loan or trigger selling … [+1873 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Cryptoverse: Is the end of the bitcoin winter nigh? - Reuters.com',
#    'description': "The crypto winter is into its ninth week and bitcoin can't shake the chills.",
#    'url': 'https://www.reuters.com/markets/europe/cryptoverse-is-end-bitcoin-winter-nigh-2022-05-24/',
#    'urlToImage': 'https://www.reuters.com/resizer/tskc85lFRu_oQwAPvUhDH1JIOVU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/FNX6RIL72VISZBW5RI2INPQ2YA.jpg',
#    'publishedAt': '2022-05-24T05:30:00Z',
#    'content': "May 24 (Reuters) - The crypto winter is into its ninth week and bitcoin can't shake the chills.\r\nFrom technicals to turnover, market indicators are flashing red or amber for the biggest cryptocurrenc… [+3967 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': "Terra 2.0 Is Now Live, Following Luna Meltdown. This Week's Top Bitcoin and Crypto News - CNET",
#    'description': 'All the bitcoin, cryptocurrency and NFT news for the week ending May 27.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/terra-2-0-launched-today-following-luna-meltdown-this-weeks-top-bitcoin-and-crypto-news/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/941676ec40a5f484a5a3421c0fab4fc66d83adf2/2022/04/23/ddcb4d2b-32be-43f0-b48f-f6d31e44bec9/crypto-story-1.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-28T20:57:40Z',
#    'content': "Terra launched a new blockchain with a new luna token, today. Seth Green's animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the … [+3854 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': "After Luna Collapse, Terra Looks to New Blockchain. This Week's Top Bitcoin and Crypto News - CNET",
#    'description': 'All the bitcoin, cryptocurrency and NFT news for the week ending May 20.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/after-luna-collapse-terra-looks-to-new-blockchain-this-weeks-top-bitcoin-and-crypto-news/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/941676ec40a5f484a5a3421c0fab4fc66d83adf2/2022/04/23/ddcb4d2b-32be-43f0-b48f-f6d31e44bec9/crypto-story-1.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-21T11:30:06Z',
#    'content': "After two linked cryptocurrencies collapsed and became almost worthless, a plan emerged to create a new blockchain for the luna cryptocurrency. Seth Green's NFTs were stolen in a phishing scam. Nike … [+3932 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': "Terra 2.0 Launch Planned Following Luna Meltdown. This Week's Top Bitcoin and Crypto News - CNET",
#    'description': 'All the bitcoin, cryptocurrency and NFT news for the week ending May 27.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/terra-2-0-launch-planned-following-luna-meltdown-this-weeks-top-bitcoin-and-crypto-news/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/941676ec40a5f484a5a3421c0fab4fc66d83adf2/2022/04/23/ddcb4d2b-32be-43f0-b48f-f6d31e44bec9/crypto-story-1.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-28T17:36:26Z',
#    'content': "Terra is launching a new blockchain with a new luna token. Seth Green's animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the Mex… [+3792 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Bitcoin Has No Future as a Payments Network, Says FTX Chief',
#    'description': "Bitcoin has no future as a payments network because of its inefficiency and high environmental costs, according to one of crypto's most influential chief executives. From a report: Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof o…",
#    'url': 'https://tech.slashdot.org/story/22/05/16/147235/bitcoin-has-no-future-as-a-payments-network-says-ftx-chief',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-05-16T14:07:00Z',
#    'content': 'Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validating blockchain transactions, which underpins bitcoin, was not capable of scaling up to cope with … [+1063 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Luis Ferré-Sadurní, Grace Ashford, Dana Rubinstein and David Yaffe-Bellany',
#    'title': 'Fight Looms Over New York’s Bid to Slow Crypto-Mining Boom',
#    'description': 'Crypto interests are lobbying Gov. Kathy Hochul to veto a groundbreaking bill that would temporarily halt new crypto-mining projects at fossil-fuel burning plants.',
#    'url': 'https://www.nytimes.com/2022/06/07/nyregion/cryptomining-ban-ny.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/06/07/nyregion/00ny-crypto1/00ny-crypto1-facebookJumbo.jpg',
#    'publishedAt': '2022-06-07T21:52:13Z',
#    'content': 'As cryptocurrencies have grown in value, Bitcoin mining has become a major industry. There are publicly traded crypto mining companies like Riot Blockchain and Marathon Digital Holdings, worth hundre… [+2001 chars]'}]}

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy")
eth_articles
# Out:
# {'status': 'ok',
#  'totalResults': 4559,
#  'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'GameStop Dunks Its Head Into the Crypto Kiddie Pool',
#    'description': 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though it’s hard to say whether its proposed population of gamers and game developers will take up the company on its belated, head-first jump into the crypto sph…',
#    'url': 'https://gizmodo.com/gamestop-crypto-nft-wallet-blockchain-1848965386',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/cd4c128b4182d7b2fba8152d7bb35733.jpg',
#    'publishedAt': '2022-05-23T21:35:00Z',
#    'content': 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Sarah Lord',
#    'title': 'GameStop Launching Digital Wallet for Cryptocurrencies, NFTs - CNET',
#    'description': "The self-custodial Ethereum wallet will have its own Google Chrome extension and can be used to complete transactions on the company's upcoming NFT marketplace.",
#    'url': 'https://www.cnet.com/tech/services-and-software/gamestop-launching-digital-wallet-for-cryptocurrencies-nfts/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/00e1b8fca281f501a409d88e2eda84a4231959db/2022/02/03/f408f29c-7a96-4e3f-b04d-53f792972f8c/gettyimages-1235868944.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-23T14:06:00Z',
#    'content': 'GameStop is going all-in on crypto. The video game retailer launched\xa0its own self-custodial Ethereum digital wallet, it said Monday. The wallet will be accessible through a Google Chrome extension an… [+1491 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'PayPal Lets Users Transfer Bitcoin and Ethereum To External Wallets',
#    'description': 'PayPal announced on Tuesday that the service now "supports the native transfer of cryptocurrencies between PayPal and other wallets and exchanges." Decrypt reports: The ability to conduct external transfers on PayPal\'s crypto platform, an image of which can b…',
#    'url': 'https://slashdot.org/story/22/06/07/2018253/paypal-lets-users-transfer-bitcoin-and-ethereum-to-external-wallets',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-06-07T23:20:00Z',
#    'content': "The ability to conduct external transfers on PayPal's crypto platform, an image of which can be seen below, will start rolling out to users today and be available to everyone in the U.S. in the next … [+687 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Eric Mack',
#    'title': 'MoonDAO Will Pick 2 of the Next Blue Origin Astronauts With the Help of NFTs - CNET',
#    'description': 'A community of cryptocurrency enthusiasts crowdfunded millions in Ethereum and used a big chunk to buy the seats on a New Shepard rocket.',
#    'url': 'https://www.cnet.com/science/space/moondao-will-pick-2-of-the-next-blue-origin-astronauts-with-the-help-of-nfts/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/20ea1456640553177755e858483e9118c6bd108c/2021/11/23/1a37a830-f657-471a-8856-cedf45e093b5/blueorigintxlaunch.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-06-09T20:56:00Z',
#    'content': 'A decentralized autonomous organization, or DAO, is giving away two seats on a Blue Origin flight to space.\r\nThis is likely the first time non-fungible tokens, or NFTs, have played a role in minting … [+4509 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Thomas Hughes',
#    'title': 'It’s Time To Get Interested In Ethereum Again',
#    'description': 'The Winklevoss twins are cutting the staff at Gemini and say crypto winter is upon us. With the price of Ethereum (Cryptocurrency: ETH) down more than 60% from the recent...',
#    'url': 'https://www.entrepreneur.com/article/429156',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/marketbeat/hero-image-marketbeat-429156.jpeg',
#    'publishedAt': '2022-06-09T06:00:00Z',
#    'content': 'Crypto Winter It May Be, But Ethereum Looks Like A Buy \r\nThe Winklevoss twins are cutting the staff at Gemini and say crypto winter is upon us. With the price of Ethereum (Cryptocurrency: ETH) down m… [+3614 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'New York passes a bill to limit bitcoin mining',
#    'description': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of Governor Kathy Hochul, who will sign it into law or veto th…",
#    'url': 'https://www.engadget.com/new-york-cryptocurrency-bill-bitcoin-mining-climate-change-161126292.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/a8217250-bdfa-11eb-bfc4-2663225cea83',
#    'publishedAt': '2022-06-03T16:11:26Z',
#    'content': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "'Pay more attention' Ethereum co-founder says of crypto crash - Reuters",
#    'description': "Ethereum's co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than $800 billion off their value.",
#    'url': 'https://www.reuters.com/markets/us/pay-more-attention-ethereum-co-founder-says-crypto-crash-2022-05-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/XsA-mJuk-UfiaqX_lbwtVZ8Egp4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/TK5SKXCQMNPBFOQOZZTJB55GHQ.jpg',
#    'publishedAt': '2022-05-25T09:33:00Z',
#    'content': "DAVOS, Switzerland, May 25 (Reuters) - Ethereum's co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Report: 'Nvidia's LHR Limiter Has Fallen, But Gamers Shouldn't Worry'",
#    'description': 'Slashdot reader Hmmmmmm shared this report from Hot Hardware:\n\nWhen Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. Ni…',
#    'url': 'https://tech.slashdot.org/story/22/05/15/190252/report-nvidias-lhr-limiter-has-fallen-but-gamers-shouldnt-worry',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/graphics_64.png',
#    'publishedAt': '2022-05-15T19:39:00Z',
#    'content': 'When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lauren Leffer',
#    'title': 'Crypto Platform Coinbase Cuts More Than 1,000 Staff',
#    'description': 'The crypto roller coaster ride continues to plummet downhill fast. Coinbase, one of the largest cryptocurrency exchange platforms, is laying off 18% of its staff, or about 1,100 employees, according to a company SEC filing. The news also came in a letter to s…',
#    'url': 'https://gizmodo.com/coinbase-lay-offs-crypto-bitcoin-1849057861',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/d247600ed4f9f90c53650a2a9b7c2f60.jpg',
#    'publishedAt': '2022-06-14T13:00:00Z',
#    'content': 'The crypto roller coaster ride continues to plummet downhill fast. Coinbase, one of the largest cryptocurrency exchange platforms, is laying off 18% of its staff, or about 1,100 employees, according … [+2041 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin gains over 5% to $31441.76 - Reuters',
#    'description': 'Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-gains-over-5-3144176-2022-06-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/lEay-or8c9TPjZOEmIjrJf3ylQk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3RKTTS2CRVM2BEEDCB2ZIPV3L4.jpg',
#    'publishedAt': '2022-06-06T20:11:00Z',
#    'content': "June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world's biggest and best-known cryptocurrency is down 34.8% from the year's high… [+335 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 12.1% to $23366 - Reuters',
#    'description': 'Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-falls-121-23366-2022-06-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/2xcvLrlBIq1EK8-72AwbhUzHdkM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/NOU4XZOJJNNOHH57DRGF5PAQSM.jpg',
#    'publishedAt': '2022-06-13T20:38:00Z',
#    'content': "June 13 (Reuters) - Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 51.6% from t… [+357 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Are Unfriendly AI the Biggest Risk to Humanity?',
#    'description': '"Ethereum creator Vitalik Buterin believes that unfriendly artificial intelligence poses the biggest risk to humanity..." reports a recent article from Benzinga:\n\n[In a tweet] Buterin shared a paper by AI theorist and writer Eliezer Yudkowsky that made a case…',
#    'url': 'https://slashdot.org/story/22/06/11/0435215/are-unfriendly-ai-the-biggest-risk-to-humanity',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#    'publishedAt': '2022-06-11T17:34:00Z',
#    'content': "[In a tweet] Buterin shared a paper by AI theorist and writer Eliezer Yudkowsky that made a case for why the current research community isn't doing enough to prevent a potential future catastrophe at… [+409 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'YouTube accused of failing to tackle fake Elon Musk livestream scams',
#    'description': 'YouTube is being criticised for failing to tackle a network of scammers streaming fake Elon Musk videos.',
#    'url': 'https://www.bbc.co.uk/news/technology-61749120',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/159D6/production/_125343588_musklivestream.jpg',
#    'publishedAt': '2022-06-09T23:00:19Z',
#    'content': 'YouTube is being criticised for failing to tackle a network of cyber-criminals streaming fake Elon Musk videos to scam viewers.\r\nThe criminals are hijacking YouTube accounts and using the videos to p… [+3851 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Weekly NFT sales plunge 50% to $255 million amid crypto bear market. These were the 5 best-selling digital collections.',
#    'description': 'Total NFT sales volume hit $29 billion over the past year as artists, investors, and entrepreneurs descend upon the nascent Web3 space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bored-ape-yacht-club-reclaims-top-spot-weekly-nft-sales-2022-5',
#    'urlToImage': 'https://i.insider.com/628508651aa29100196a381f?width=1200&format=jpeg',
#    'publishedAt': '2022-05-18T15:53:28Z',
#    'content': 'The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'John Monarch',
#    'title': 'Can Blockchain Help Fix Broken Supply Chains in 2022?',
#    'description': 'Blockchain in Supply Chain was a hot topic - then fell very quiet. Where is it today?',
#    'url': 'https://www.entrepreneur.com/article/426351',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1653325433-GettyImages-1194691729.jpg',
#    'publishedAt': '2022-06-03T14:00:00Z',
#    'content': 'We first heard about the potential of blockchain in supply chains several years ago, and almost immediately were thrust into a cycle of hype and hope of what they could do for us, followed by a "trou… [+4785 chars]'},
#   {'source': {'id': None, 'name': 'Boing Boing'},
#    'author': 'Jennifer Sandlin',
#    'title': 'The Hollywoodization of crypto is a moral disaster',
#    'description': 'Every time you turn around, it seems another celebrity is hawking cryptocurrency or NFTs. Influencer Kim Kardashian, boxer Floyd Mayweather, and former NBA athlete Paul Pierce have all promoted Ethereum Max; Matt Damon has starred in commercials for Crypto.co…',
#    'url': 'https://boingboing.net/2022/06/07/the-hollywoodization-of-crypto-is-a-moral-disaster.html',
#    'urlToImage': 'https://i0.wp.com/boingboing.net/wp-content/uploads/2022/06/btc.jpeg?fit=1200%2C900&ssl=1',
#    'publishedAt': '2022-06-07T22:19:23Z',
#    'content': 'Every time you turn around, it seems another celebrity is hawking cryptocurrency or NFTs. Influencer Kim Kardashian, boxer Floyd Mayweather, and former NBA athlete Paul Pierce have all promoted Ether… [+2773 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Linda John',
#    'title': 'White Label NFT Marketplace is the New Way to Launch Digital Platforms',
#    'description': 'NFT marketplaces are becoming the trend, and each and every one of them has started to build their own NFT marketplaces. However, few people require a marketplace that could be launched in the market at the earliest, and few are okay with the ones that take t…',
#    'url': 'https://readwrite.com/white-label-nft-marketplace-is-the-new-way-to-launch-digital-platforms/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/05/White-Label-NFT-Marketplace.jpg',
#    'publishedAt': '2022-06-09T15:00:37Z',
#    'content': 'NFT marketplaces are becoming the trend, and each and every one of them has started to build their own NFT marketplaces. \r\nHowever, few people require a marketplace that could be launched in the mark… [+5873 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': 'Solana tumbles as its blockchain network suffers 2nd outage in a month',
#    'description': 'Solana suffered similar turbulence on May 1, when its network remained down for roughly seven hours.',
#    'url': 'https://markets.businessinsider.com/news/currencies/solana-price-sol-tumbles-blockchain-network-suffers-2nd-outage-month-2022-6',
#    'urlToImage': 'https://i.insider.com/6297c14ce319620018a80e29?width=1200&format=jpeg',
#    'publishedAt': '2022-06-01T19:58:36Z',
#    'content': 'Solana, the third largest cryptocurrency by market capitalization, fell 10% Wednesday following reports of its blockchain network suffering another outage.\xa0\r\nThe blockchain had not produced new block… [+566 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Weekly NFT sales drop 23% to $191 million amid crypto bear market. These were the 5 best-selling digital collections.',
#    'description': 'Total NFT sales volume hit $29 billion over the past year as artists, investors, and entrepreneurs descend upon the nascent Web3 space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/meebits-rise-top-spot-weekly-nft-sales-crypto-bored-apes-2022-5',
#    'urlToImage': 'https://i.insider.com/627281def6bd4b0019cb550c?width=1200&format=jpeg',
#    'publishedAt': '2022-05-25T14:55:04Z',
#    'content': 'The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2830 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Jon Brodkin',
#    'title': 'NY passes US-first moratorium on reviving fossil fuel plants to mine crypto',
#    'description': 'If signed by gov., bill would halt permits while state studies environmental impact.',
#    'url': 'https://arstechnica.com/tech-policy/2022/06/ny-passes-us-first-moratorium-on-reviving-fossil-fuel-plants-to-mine-crypto/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2022/06/getty-bitcoin-760x380.jpg',
#    'publishedAt': '2022-06-03T20:26:26Z',
#    'content': "6 with 6 posters participating\r\nNew York's state legislature approved a bill that would prevent fossil fuel power plants from being revived to power cryptocurrency mining operations. If signed by Gov… [+3200 chars]"}]}

# %%
# Function for getting sentiment score DF's 
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                based_on : text,
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos
            })
        except AttributeError:
            pass
    df = pd.DataFrame(sentiments)
    return df

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sent_df = get_sentiment_score(btc_articles, "content")
btc_sent_df
# Out:
#                                               content  Compound  Negative  \
# 0   New York lawmakers have passed a bill\r\n that...   -0.5574     0.098
# 1   Rapper and entrepreneur Shawn Carter, better k...    0.4404     0.000
# 2   A new study on bitcoin calls into question whe...    0.5267     0.000
# 3   Image caption, President Faustin-Archange Toua...    0.5106     0.000
# 4   You can now reportedly pay for your burritos a...   -0.1027     0.040
# 5   By Joe TidyCyber reporter \r\nCryptocurrencies...    0.2960     0.074
# 6   (CNN)El Salvador has embraced Bitcoin like no ...    0.1027     0.046
# 7   As a kid, I remember when my father tried to u...    0.3818     0.052
# 8   Customers at Chipotle will now be able to pay ...    0.3182     0.040
# 9   Celsius has not said what it plans to do next\...    0.0000     0.000
# 10  Photo Illustration by Grayson Blackmon / The V...   -0.4767     0.103
# 11  June 6 (Reuters) - Bitcoin rose 5.2% to $31,44...    0.0000     0.000
# 12  June 13 (Reuters) - Bitcoin dropped 12.1% to $...   -0.3818     0.075
# 13  SINGAPORE, June 14 (Reuters) - Bitcoin neared ...    0.0000     0.000
# 14  May 24 (Reuters) - The crypto winter is into i...    0.1326     0.000
# 15  Terra launched a new blockchain with a new lun...   -0.2960     0.084
# 16  After two linked cryptocurrencies collapsed an...   -0.8593     0.300
# 17  Terra is launching a new blockchain with a new...   -0.4019     0.083
# 18  Sam Bankman-Fried, founder of the digital asse...    0.4051     0.059
# 19  As cryptocurrencies have grown in value, Bitco...    0.2960     0.099
#
#     Neutral  Positive
# 0     0.902     0.000
# 1     0.923     0.077
# 2     0.876     0.124
# 3     0.836     0.164
# 4     0.960     0.000
# 5     0.792     0.134
# 6     0.867     0.087
# 7     0.833     0.114
# 8     0.883     0.077
# 9     1.000     0.000
# 10    0.897     0.000
# 11    1.000     0.000
# 12    0.925     0.000
# 13    1.000     0.000
# 14    0.956     0.044
# 15    0.838     0.079
# 16    0.646     0.054
# 17    0.879     0.039
# 18    0.809     0.132
# 19    0.714     0.187

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sent_df = get_sentiment_score(eth_articles, "content")
eth_sent_df
# Out:
#                                               content  Compound  Negative  \
# 0   GameStop has officially thrown itself headlong...   -0.1027     0.040
# 1   GameStop is going all-in on crypto. The video ...    0.1280     0.000
# 2   The ability to conduct external transfers on P...    0.3182     0.000
# 3   A decentralized autonomous organization, or DA...    0.5859     0.000
# 4   Crypto Winter It May Be, But Ethereum Looks Li...    0.3612     0.044
# 5   New York lawmakers have passed a bill\r\n that...   -0.5574     0.098
# 6   DAVOS, Switzerland, May 25 (Reuters) - Ethereu...    0.0258     0.000
# 7   When Nvidia launched its Ampere Lite Hash Rate...   -0.3818     0.085
# 8   The crypto roller coaster ride continues to pl...    0.0000     0.000
# 9   June 6 (Reuters) - Bitcoin rose 5.2% to $31,44...    0.0000     0.000
# 10  June 13 (Reuters) - Bitcoin dropped 12.1% to $...   -0.3818     0.075
# 11  [In a tweet] Buterin shared a paper by AI theo...   -0.4404     0.119
# 12  YouTube is being criticised for failing to tac...   -0.9485     0.372
# 13  The cryptocurrency boom over the past few year...   -0.1531     0.045
# 14  We first heard about the potential of blockcha...    0.4404     0.000
# 15  Every time you turn around, it seems another c...    0.4215     0.000
# 16  NFT marketplaces are becoming the trend, and e...    0.1280     0.000
# 17  Solana, the third largest cryptocurrency by ma...   -0.4767     0.100
# 18  The cryptocurrency boom over the past few year...   -0.1531     0.045
# 19  6 with 6 posters participating\r\nNew York's s...    0.4404     0.000
#
#     Neutral  Positive
# 0     0.960     0.000
# 1     0.954     0.046
# 2     0.941     0.059
# 3     0.866     0.134
# 4     0.875     0.081
# 5     0.902     0.000
# 6     0.966     0.034
# 7     0.847     0.069
# 8     1.000     0.000
# 9     1.000     0.000
# 10    0.925     0.000
# 11    0.786     0.095
# 12    0.628     0.000
# 13    0.955     0.000
# 14    0.925     0.075
# 15    0.917     0.083
# 16    0.958     0.042
# 17    0.900     0.000
# 18    0.955     0.000
# 19    0.878     0.122

# %%
# Describe the Bitcoin Sentiment
btc_sent_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.016715   0.057650   0.876800   0.065600
# std     0.398865   0.068859   0.092058   0.061384
# min    -0.859300   0.000000   0.646000   0.000000
# 25%    -0.317450   0.000000   0.835250   0.000000
# 50%     0.051350   0.049000   0.881000   0.065500
# 75%     0.334100   0.083250   0.932750   0.116500
# max     0.526700   0.300000   1.000000   0.187000

# %%
# Describe the Ethereum Sentiment
eth_sent_df.describe()
# Out:
#         Compound   Negative    Neutral  Positive
# count  20.000000  20.000000  20.000000  20.00000
# mean   -0.037305   0.051150   0.906900   0.04200
# std     0.405662   0.085919   0.084171   0.04527
# min    -0.948500   0.000000   0.628000   0.00000
# 25%    -0.381800   0.000000   0.877250   0.00000
# 50%     0.000000   0.020000   0.925000   0.03800
# 75%     0.328950   0.077500   0.955750   0.07650
# max     0.585900   0.372000   1.000000   0.13400

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin 0.065600
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum 0.585900
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin 0.187000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words("english"))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean.lower())
    
    #lemmatizer = WordNetLemmatizer()
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw)]

    return tokens

# %%
btc_sent_df.iloc[0]['content']
# Out:
# "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars]"

# %%
# Create a new tokens column for Bitcoin
btc_sent_df['tokens'] = btc_sent_df['content'].apply(tokenizer)
btc_sent_df
# Out:
#                                               content  Compound  Negative  \
# 0   New York lawmakers have passed a bill\r\n that...   -0.5574     0.098
# 1   Rapper and entrepreneur Shawn Carter, better k...    0.4404     0.000
# 2   A new study on bitcoin calls into question whe...    0.5267     0.000
# 3   Image caption, President Faustin-Archange Toua...    0.5106     0.000
# 4   You can now reportedly pay for your burritos a...   -0.1027     0.040
# 5   By Joe TidyCyber reporter \r\nCryptocurrencies...    0.2960     0.074
# 6   (CNN)El Salvador has embraced Bitcoin like no ...    0.1027     0.046
# 7   As a kid, I remember when my father tried to u...    0.3818     0.052
# 8   Customers at Chipotle will now be able to pay ...    0.3182     0.040
# 9   Celsius has not said what it plans to do next\...    0.0000     0.000
# 10  Photo Illustration by Grayson Blackmon / The V...   -0.4767     0.103
# 11  June 6 (Reuters) - Bitcoin rose 5.2% to $31,44...    0.0000     0.000
# 12  June 13 (Reuters) - Bitcoin dropped 12.1% to $...   -0.3818     0.075
# 13  SINGAPORE, June 14 (Reuters) - Bitcoin neared ...    0.0000     0.000
# 14  May 24 (Reuters) - The crypto winter is into i...    0.1326     0.000
# 15  Terra launched a new blockchain with a new lun...   -0.2960     0.084
# 16  After two linked cryptocurrencies collapsed an...   -0.8593     0.300
# 17  Terra is launching a new blockchain with a new...   -0.4019     0.083
# 18  Sam Bankman-Fried, founder of the digital asse...    0.4051     0.059
# 19  As cryptocurrencies have grown in value, Bitco...    0.2960     0.099
#
#     Neutral  Positive                                             tokens
# 0     0.902     0.000  [new, york, lawmaker, passed, bill, would, tem...
# 1     0.923     0.077  [rapper, entrepreneur, shawn, carter, better, ...
# 2     0.876     0.124  [new, study, bitcoin, call, question, whether,...
# 3     0.836     0.164  [image, caption, president, faustinarchange, t...
# 4     0.960     0.000  [reportedly, pay, burrito, taco, bitcoin, digi...
# 5     0.792     0.134  [joe, tidycyber, reporter, cryptocurrencies, c...
# 6     0.867     0.087  [cnnel, salvador, ha, embraced, bitcoin, like,...
# 7     0.833     0.114  [kid, remember, father, tried, use, broom, han...
# 8     0.883     0.077  [customer, chipotle, able, pay, burrito, crypt...
# 9     1.000     0.000  [celsius, ha, said, plan, nextexhibition, expe...
# 10    0.897     0.000  [photo, illustration, grayson, blackmon, verge...
# 11    1.000     0.000  [june, 6, reuters, bitcoin, rose, 52, 3144176,...
# 12    0.925     0.000  [june, 13, reuters, bitcoin, dropped, 121, 233...
# 13    1.000     0.000  [singapore, june, 14, reuters, bitcoin, neared...
# 14    0.956     0.044  [may, 24, reuters, crypto, winter, ninth, week...
# 15    0.838     0.079  [terra, launched, new, blockchain, new, luna, ...
# 16    0.646     0.054  [two, linked, cryptocurrencies, collapsed, bec...
# 17    0.879     0.039  [terra, launching, new, blockchain, new, luna,...
# 18    0.809     0.132  [sam, bankmanfried, founder, digital, asset, e...
# 19    0.714     0.187  [cryptocurrencies, grown, value, bitcoin, mini...

# %%
# Create a new tokens column for Ethereum
eth_sent_df['tokens'] = eth_sent_df['content'].apply(tokenizer)
eth_sent_df
# Out:
#                                               content  Compound  Negative  \
# 0   GameStop has officially thrown itself headlong...   -0.1027     0.040
# 1   GameStop is going all-in on crypto. The video ...    0.1280     0.000
# 2   The ability to conduct external transfers on P...    0.3182     0.000
# 3   A decentralized autonomous organization, or DA...    0.5859     0.000
# 4   Crypto Winter It May Be, But Ethereum Looks Li...    0.3612     0.044
# 5   New York lawmakers have passed a bill\r\n that...   -0.5574     0.098
# 6   DAVOS, Switzerland, May 25 (Reuters) - Ethereu...    0.0258     0.000
# 7   When Nvidia launched its Ampere Lite Hash Rate...   -0.3818     0.085
# 8   The crypto roller coaster ride continues to pl...    0.0000     0.000
# 9   June 6 (Reuters) - Bitcoin rose 5.2% to $31,44...    0.0000     0.000
# 10  June 13 (Reuters) - Bitcoin dropped 12.1% to $...   -0.3818     0.075
# 11  [In a tweet] Buterin shared a paper by AI theo...   -0.4404     0.119
# 12  YouTube is being criticised for failing to tac...   -0.9485     0.372
# 13  The cryptocurrency boom over the past few year...   -0.1531     0.045
# 14  We first heard about the potential of blockcha...    0.4404     0.000
# 15  Every time you turn around, it seems another c...    0.4215     0.000
# 16  NFT marketplaces are becoming the trend, and e...    0.1280     0.000
# 17  Solana, the third largest cryptocurrency by ma...   -0.4767     0.100
# 18  The cryptocurrency boom over the past few year...   -0.1531     0.045
# 19  6 with 6 posters participating\r\nNew York's s...    0.4404     0.000
#
#     Neutral  Positive                                             tokens
# 0     0.960     0.000  [gamestop, ha, officially, thrown, headlong, w...
# 1     0.954     0.046  [gamestop, going, allin, crypto, video, game, ...
# 2     0.941     0.059  [ability, conduct, external, transfer, paypals...
# 3     0.866     0.134  [decentralized, autonomous, organization, dao,...
# 4     0.875     0.081  [crypto, winter, may, ethereum, look, like, bu...
# 5     0.902     0.000  [new, york, lawmaker, passed, bill, would, tem...
# 6     0.966     0.034  [davos, switzerland, may, 25, reuters, ethereu...
# 7     0.847     0.069  [nvidia, launched, ampere, lite, hash, rate, l...
# 8     1.000     0.000  [crypto, roller, coaster, ride, continues, plu...
# 9     1.000     0.000  [june, 6, reuters, bitcoin, rose, 52, 3144176,...
# 10    0.925     0.000  [june, 13, reuters, bitcoin, dropped, 121, 233...
# 11    0.786     0.095  [tweet, buterin, shared, paper, ai, theorist, ...
# 12    0.628     0.000  [youtube, criticised, failing, tackle, network...
# 13    0.955     0.000  [cryptocurrency, boom, past, year, ha, helped,...
# 14    0.925     0.075  [first, heard, potential, blockchain, supply, ...
# 15    0.917     0.083  [every, time, turn, around, seems, another, ce...
# 16    0.958     0.042  [nft, marketplace, becoming, trend, every, one...
# 17    0.900     0.000  [solana, third, largest, cryptocurrency, marke...
# 18    0.955     0.000  [cryptocurrency, boom, past, year, ha, helped,...
# 19    0.878     0.122  [6, 6, poster, participatingnew, york, state, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Get token function
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_token = get_token(btc_sent_df)
eth_token = get_token(eth_sent_df)

# %%
# N-gram Function
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

# %%
# Generate the Bitcoin N-grams where N=2
btc_bigram = bigram_counter(btc_token, 2)
btc_bigram
# Out:
# {('new', 'york'): 1,
#  ('york', 'lawmaker'): 1,
#  ('lawmaker', 'passed'): 1,
#  ('passed', 'bill'): 1,
#  ('bill', 'would'): 1,
#  ('would', 'temporarily'): 1,
#  ('temporarily', 'ban'): 1,
#  ('ban', 'new'): 1,
#  ('new', 'bitcoin'): 1,
#  ('bitcoin', 'mining'): 2,
#  ('mining', 'operation'): 1,
#  ('operation', 'early'): 1,
#  ('early', 'friday'): 1,
#  ('friday', 'state'): 1,
#  ('state', 'senator'): 1,
#  ('senator', 'voted'): 1,
#  ('voted', '3627'): 1,
#  ('3627', 'pas'): 1,
#  ('pas', 'legislation'): 1,
#  ('legislation', 'bound'): 1,
#  ('bound', 'desk'): 1,
#  ('desk', '2036'): 1,
#  ('2036', 'char'): 1,
#  ('char', 'rapper'): 1,
#  ('rapper', 'entrepreneur'): 1,
#  ('entrepreneur', 'shawn'): 1,
#  ('shawn', 'carter'): 1,
#  ('carter', 'better'): 1,
#  ('better', 'known'): 1,
#  ('known', 'jayz'): 1,
#  ('jayz', 'bringing'): 1,
#  ('bringing', 'bitcoin'): 1,
#  ('bitcoin', 'place'): 1,
#  ('place', 'grew'): 1,
#  ('grew', 'thursday'): 1,
#  ('thursday', 'jayz'): 1,
#  ('jayz', 'former'): 1,
#  ('former', 'twitter'): 1,
#  ('twitter', 'ceo'): 1,
#  ('ceo', 'jack'): 1,
#  ('jack', 'dorsey'): 1,
#  ('dorsey', 'announced'): 1,
#  ('announced', 'launch'): 1,
#  ('launch', 'bitcoin'): 1,
#  ('bitcoin', '2920'): 1,
#  ('2920', 'char'): 1,
#  ('char', 'new'): 1,
#  ('new', 'study'): 1,
#  ('study', 'bitcoin'): 1,
#  ('bitcoin', 'call'): 1,
#  ('call', 'question'): 1,
#  ('question', 'whether'): 1,
#  ('whether', 'digital'): 1,
#  ('digital', 'currency'): 2,
#  ('currency', 'truly'): 1,
#  ('truly', 'decentralized'): 1,
#  ('decentralized', 'anonymous'): 1,
#  ('anonymous', 'biggest'): 1,
#  ('biggest', 'devotee'): 1,
#  ('devotee', 'would'): 1,
#  ('would', 'believe'): 1,
#  ('believe', 'researcher'): 1,
#  ('researcher', 'baylor'): 1,
#  ('baylor', 'rice'): 1,
#  ('rice', '7343'): 1,
#  ('7343', 'char'): 1,
#  ('char', 'image'): 1,
#  ('image', 'caption'): 1,
#  ('caption', 'president'): 1,
#  ('president', 'faustinarchange'): 1,
#  ('faustinarchange', 'touadra'): 1,
#  ('touadra', 'want'): 1,
#  ('want', 'rethink'): 1,
#  ('rethink', 'country'): 1,
#  ('country', 'economic'): 1,
#  ('economic', 'philosophythe'): 1,
#  ('philosophythe', 'central'): 1,
#  ('central', 'african'): 1,
#  ('african', 'republic'): 1,
#  ('republic', 'decision'): 1,
#  ('decision', 'adopt'): 1,
#  ('adopt', 'bitcoin'): 1,
#  ('bitcoin', 'legal'): 1,
#  ('legal', 'tender'): 2,
#  ('tender', 'came'): 1,
#  ('came', 'surprise'): 1,
#  ('surprise', '8881'): 1,
#  ('8881', 'char'): 1,
#  ('char', 'reportedly'): 1,
#  ('reportedly', 'pay'): 1,
#  ('pay', 'burrito'): 2,
#  ('burrito', 'taco'): 1,
#  ('taco', 'bitcoin'): 1,
#  ('bitcoin', 'digital'): 1,
#  ('currency', 'case'): 1,
#  ('case', 'dont'): 1,
#  ('dont', 'mind'): 1,
#  ('mind', 'spending'): 1,
#  ('spending', 'coin'): 1,
#  ('coin', 'directly'): 1,
#  ('directly', 'instead'): 1,
#  ('instead', 'going'): 1,
#  ('going', 'exchange'): 1,
#  ('exchange', 'first'): 1,
#  ('first', 'flexa'): 1,
#  ('flexa', 'h'): 1,
#  ('h', '1428'): 1,
#  ('1428', 'char'): 1,
#  ('char', 'joe'): 1,
#  ('joe', 'tidycyber'): 1,
#  ('tidycyber', 'reporter'): 1,
#  ('reporter', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'continued'): 1,
#  ('continued', 'tumble'): 1,
#  ('tumble', 'week'): 1,
#  ('week', 'billion'): 1,
#  ('billion', 'wiped'): 1,
#  ('wiped', 'value'): 1,
#  ('value', 'token'): 1,
#  ('token', 'like'): 1,
#  ('like', 'bitcoin'): 1,
#  ('bitcoin', 'crash'): 1,
#  ('crash', 'affecting'): 1,
#  ('affecting', 'investor'): 1,
#  ('investor', 'worldwide'): 1,
#  ('worldwide', 'including'): 1,
#  ('including', 'go'): 1,
#  ('go', '6815'): 1,
#  ('6815', 'char'): 1,
#  ('char', 'cnnel'): 1,
#  ('cnnel', 'salvador'): 1,
#  ('salvador', 'ha'): 1,
#  ('ha', 'embraced'): 1,
#  ('embraced', 'bitcoin'): 1,
#  ('bitcoin', 'like'): 1,
#  ('like', 'country'): 1,
#  ('country', 'government'): 1,
#  ('government', 'purchasing'): 1,
#  ('purchasing', 'hundred'): 1,
#  ('hundred', 'coin'): 1,
#  ('coin', 'last'): 1,
#  ('last', 'year'): 1,
#  ('year', 'announced'): 1,
#  ('announced', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'would'): 1,
#  ('would', 'become'): 1,
#  ('become', 'legal'): 1,
#  ('tender', '842'): 1,
#  ('842', 'char'): 1,
#  ('char', 'kid'): 1,
#  ('kid', 'remember'): 1,
#  ('remember', 'father'): 1,
#  ('father', 'tried'): 1,
#  ('tried', 'use'): 1,
#  ('use', 'broom'): 1,
#  ('broom', 'handle'): 1,
#  ('handle', 'last'): 1,
#  ('last', 'ditch'): 1,
#  ('ditch', 'effort'): 1,
#  ('effort', 'support'): 1,
#  ('support', 'roof'): 1,
#  ('roof', 'wa'): 1,
#  ('wa', 'collapsing'): 1,
#  ('collapsing', 'weight'): 1,
#  ('weight', 'nearly'): 1,
#  ('nearly', 'three'): 1,
#  ('three', 'foot'): 1,
#  ('foot', 'snow'): 1,
#  ('snow', 'guess'): 1,
#  ('guess', 'well'): 1,
#  ('well', '3390'): 1,
#  ('3390', 'char'): 1,
#  ('char', 'customer'): 1,
#  ('customer', 'chipotle'): 1,
#  ('chipotle', 'able'): 1,
#  ('able', 'pay'): 1,
#  ('burrito', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'including'): 1,
#  ('including', 'bitcoin'): 1,
#  ('bitcoin', 'ether'): 1,
#  ('ether', 'dogecoin'): 1,
#  ('dogecoin', 'move'): 1,
#  ('move', 'could'): 1,
#  ('could', 'help'): 1,
#  ('help', 'crypto'): 1,
#  ('crypto', 'become'): 1,
#  ('become', 'mainstream'): 1,
#  ('mainstream', 'according'): 1,
#  ('according', '3130'): 1,
#  ('3130', 'char'): 1,
#  ('char', 'celsius'): 1,
#  ('celsius', 'ha'): 1,
#  ('ha', 'said'): 1,
#  ('said', 'plan'): 1,
#  ('plan', 'nextexhibition'): 1,
#  ('nextexhibition', 'experience'): 1,
#  ('experience', 'zone'): 1,
#  ('zone', 'paris'): 1,
#  ('paris', 'nft'): 1,
#  ('nft', 'day'): 1,
#  ('day', 'conferencethe'): 1,
#  ('conferencethe', 'celsius'): 1,
#  ('celsius', 'network'): 1,
#  ('network', 'decentralized'): 1,
#  ('decentralized', 'finance'): 1,
#  ('finance', 'defi'): 1,
#  ('defi', 'platform'): 1,
#  ('platform', 'one'): 1,
#  ('one', 'largest'): 1,
#  ('largest', 'cry'): 1,
#  ('cry', '3737'): 1,
#  ('3737', 'char'): 1,
#  ('char', 'photo'): 1,
#  ('photo', 'illustration'): 1,
#  ('illustration', 'grayson'): 1,
#  ('grayson', 'blackmon'): 1,
#  ('blackmon', 'verge'): 1,
#  ('verge', 'photo'): 1,
#  ('photo', 'oliyarnyk'): 1,
#  ('oliyarnyk', 'ccbysa40'): 1,
#  ('ccbysa40', 'michael'): 1,
#  ('michael', 'chobanian'): 1,
#  ('chobanian', 'president'): 1,
#  ('president', 'blockchain'): 1,
#  ('blockchain', 'association'): 1,
#  ('association', 'ukraine'): 1,
#  ('ukraine', 'terrible'): 1,
#  ('terrible', 'unprovoked'): 1,
#  ('unprovoked', 'wa'): 1,
#  ('wa', '52103'): 1,
#  ('52103', 'char'): 1,
#  ('char', 'june'): 2,
#  ('june', '6'): 1,
#  ('6', 'reuters'): 1,
#  ('reuters', 'bitcoin'): 3,
#  ('bitcoin', 'rose'): 1,
#  ('rose', '52'): 1,
#  ('52', '3144176'): 1,
#  ('3144176', '2000'): 1,
#  ('2000', 'gmt'): 1,
#  ('gmt', 'monday'): 2,
#  ('monday', 'adding'): 1,
#  ('adding', '155278'): 1,
#  ('155278', 'previous'): 1,
#  ('previous', 'closethe'): 1,
#  ('closethe', 'world'): 1,
#  ('world', 'biggest'): 2,
#  ('biggest', 'bestknown'): 2,
#  ('bestknown', 'cryptocurrency'): 2,
#  ('cryptocurrency', '348'): 1,
#  ('348', 'year'): 1,
#  ('year', 'high'): 1,
#  ('high', '335'): 1,
#  ('335', 'char'): 1,
#  ('june', '13'): 1,
#  ('13', 'reuters'): 1,
#  ('bitcoin', 'dropped'): 1,
#  ('dropped', '121'): 1,
#  ('121', '23366'): 1,
#  ('23366', '2002'): 1,
#  ('2002', 'gmt'): 1,
#  ('monday', 'losing'): 1,
#  ('losing', '321895'): 1,
#  ('321895', 'previous'): 1,
#  ('previous', 'closebitcoin'): 1,
#  ('closebitcoin', 'world'): 1,
#  ('cryptocurrency', '516'): 1,
#  ('516', '357'): 1,
#  ('357', 'char'): 1,
#  ('char', 'singapore'): 1,
#  ('singapore', 'june'): 1,
#  ('june', '14'): 1,
#  ('14', 'reuters'): 1,
#  ('bitcoin', 'neared'): 1,
#  ('neared', 'price'): 1,
#  ('price', 'level'): 1,
#  ('level', 'tuesday'): 1,
#  ('tuesday', 'could'): 1,
#  ('could', 'force'): 1,
#  ('force', 'software'): 1,
#  ('software', 'firm'): 1,
#  ('firm', 'microstrategy'): 1,
#  ('microstrategy', 'inc'): 1,
#  ('inc', 'mstro'): 1,
#  ('mstro', 'stake'): 1,
#  ('stake', 'token'): 1,
#  ('token', 'bitcoinbacked'): 1,
#  ('bitcoinbacked', 'loan'): 1,
#  ('loan', 'trigger'): 1,
#  ('trigger', 'selling'): 1,
#  ('selling', '1873'): 1,
#  ('1873', 'char'): 1,
#  ('char', 'may'): 1,
#  ('may', '24'): 1,
#  ('24', 'reuters'): 1,
#  ('reuters', 'crypto'): 1,
#  ('crypto', 'winter'): 1,
#  ('winter', 'ninth'): 1,
#  ('ninth', 'week'): 1,
#  ('week', 'bitcoin'): 1,
#  ('bitcoin', 'cant'): 1,
#  ('cant', 'shake'): 1,
#  ('shake', 'chillsfrom'): 1,
#  ('chillsfrom', 'technical'): 1,
#  ('technical', 'turnover'): 1,
#  ('turnover', 'market'): 1,
#  ('market', 'indicator'): 1,
#  ('indicator', 'flashing'): 1,
#  ('flashing', 'red'): 1,
#  ('red', 'amber'): 1,
#  ('amber', 'biggest'): 1,
#  ('biggest', 'cryptocurrenc'): 1,
#  ('cryptocurrenc', '3967'): 1,
#  ('3967', 'char'): 1,
#  ('char', 'terra'): 2,
#  ('terra', 'launched'): 1,
#  ('launched', 'new'): 1,
#  ('new', 'blockchain'): 3,
#  ('blockchain', 'new'): 2,
#  ('new', 'luna'): 2,
#  ('luna', 'token'): 2,
#  ('token', 'today'): 1,
#  ('today', 'seth'): 1,
#  ('seth', 'green'): 3,
#  ('green', 'animated'): 2,
#  ('animated', 'show'): 2,
#  ('show', 'starring'): 2,
#  ('starring', 'stolen'): 2,
#  ('stolen', 'nft'): 2,
#  ('nft', 'air'): 2,
#  ('air', 'largest'): 2,
#  ('largest', 'stablecoin'): 2,
#  ('stablecoin', 'issuer'): 2,
#  ('issuer', 'world'): 2,
#  ('world', 'launched'): 2,
#  ('launched', 'token'): 2,
#  ('token', '3854'): 1,
#  ('3854', 'char'): 1,
#  ('char', 'two'): 1,
#  ('two', 'linked'): 1,
#  ('linked', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'collapsed'): 1,
#  ('collapsed', 'became'): 1,
#  ('became', 'almost'): 1,
#  ('almost', 'worthless'): 1,
#  ('worthless', 'plan'): 1,
#  ('plan', 'emerged'): 1,
#  ('emerged', 'create'): 1,
#  ('create', 'new'): 1,
#  ('blockchain', 'luna'): 1,
#  ('luna', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'seth'): 1,
#  ('green', 'nfts'): 1,
#  ('nfts', 'stolen'): 1,
#  ('stolen', 'phishing'): 1,
#  ('phishing', 'scam'): 1,
#  ('scam', 'nike'): 1,
#  ('nike', '3932'): 1,
#  ('3932', 'char'): 1,
#  ('terra', 'launching'): 1,
#  ('launching', 'new'): 1,
#  ('token', 'seth'): 1,
#  ('token', 'mex'): 1,
#  ('mex', '3792'): 1,
#  ('3792', 'char'): 1,
#  ('char', 'sam'): 1,
#  ('sam', 'bankmanfried'): 1,
#  ('bankmanfried', 'founder'): 1,
#  ('founder', 'digital'): 1,
#  ('digital', 'asset'): 1,
#  ('asset', 'exchange'): 1,
#  ('exchange', 'ftx'): 1,
#  ('ftx', 'said'): 1,
#  ('said', 'proof'): 1,
#  ('proof', 'work'): 1,
#  ('work', 'system'): 1,
#  ('system', 'validating'): 1,
#  ('validating', 'blockchain'): 1,
#  ('blockchain', 'transaction'): 1,
#  ('transaction', 'underpins'): 1,
#  ('underpins', 'bitcoin'): 1,
#  ('bitcoin', 'wa'): 1,
#  ('wa', 'capable'): 1,
#  ('capable', 'scaling'): 1,
#  ('scaling', 'cope'): 1,
#  ('cope', '1063'): 1,
#  ('1063', 'char'): 1,
#  ('char', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'grown'): 1,
#  ('grown', 'value'): 1,
#  ('value', 'bitcoin'): 1,
#  ('mining', 'ha'): 1,
#  ('ha', 'become'): 1,
#  ('become', 'major'): 1,
#  ('major', 'industry'): 1,
#  ('industry', 'publicly'): 1,
#  ('publicly', 'traded'): 1,
#  ('traded', 'crypto'): 1,
#  ('crypto', 'mining'): 1,
#  ('mining', 'company'): 1,
#  ('company', 'like'): 1,
#  ('like', 'riot'): 1,
#  ('riot', 'blockchain'): 1,
#  ('blockchain', 'marathon'): 1,
#  ('marathon', 'digital'): 1,
#  ('digital', 'holding'): 1,
#  ('holding', 'worth'): 1,
#  ('worth', 'hundre'): 1,
#  ('hundre', '2001'): 1,
#  ('2001', 'char'): 1}

# %%
# Generate the Ethereum N-grams where N=2
eth_bigram = bigram_counter(eth_token, 2)
eth_bigram
# Out:
# {('gamestop', 'ha'): 1,
#  ('ha', 'officially'): 1,
#  ('officially', 'thrown'): 1,
#  ('thrown', 'headlong'): 1,
#  ('headlong', 'web3'): 1,
#  ('web3', 'viper'): 1,
#  ('viper', 'nest'): 1,
#  ('nest', 'new'): 1,
#  ('new', 'app'): 1,
#  ('app', 'release'): 1,
#  ('release', 'though'): 1,
#  ('though', 'hard'): 1,
#  ('hard', 'say'): 1,
#  ('say', 'whether'): 1,
#  ('whether', 'proposed'): 1,
#  ('proposed', 'population'): 1,
#  ('population', 'gamers'): 1,
#  ('gamers', 'game'): 1,
#  ('game', 'developer'): 1,
#  ('developer', 'take'): 1,
#  ('take', '3255'): 1,
#  ('3255', 'char'): 1,
#  ('char', 'gamestop'): 1,
#  ('gamestop', 'going'): 1,
#  ('going', 'allin'): 1,
#  ('allin', 'crypto'): 1,
#  ('crypto', 'video'): 1,
#  ('video', 'game'): 1,
#  ('game', 'retailer'): 1,
#  ('retailer', 'launchedits'): 1,
#  ('launchedits', 'selfcustodial'): 1,
#  ('selfcustodial', 'ethereum'): 1,
#  ('ethereum', 'digital'): 1,
#  ('digital', 'wallet'): 1,
#  ('wallet', 'said'): 1,
#  ('said', 'monday'): 1,
#  ('monday', 'wallet'): 1,
#  ('wallet', 'accessible'): 1,
#  ('accessible', 'google'): 1,
#  ('google', 'chrome'): 1,
#  ('chrome', 'extension'): 1,
#  ('extension', '1491'): 1,
#  ('1491', 'char'): 1,
#  ('char', 'ability'): 1,
#  ('ability', 'conduct'): 1,
#  ('conduct', 'external'): 1,
#  ('external', 'transfer'): 1,
#  ('transfer', 'paypals'): 1,
#  ('paypals', 'crypto'): 1,
#  ('crypto', 'platform'): 1,
#  ('platform', 'image'): 1,
#  ('image', 'seen'): 1,
#  ('seen', 'start'): 1,
#  ('start', 'rolling'): 1,
#  ('rolling', 'user'): 1,
#  ('user', 'today'): 1,
#  ('today', 'available'): 1,
#  ('available', 'everyone'): 1,
#  ('everyone', 'u'): 1,
#  ('u', 'next'): 1,
#  ('next', '687'): 1,
#  ('687', 'char'): 1,
#  ('char', 'decentralized'): 1,
#  ('decentralized', 'autonomous'): 1,
#  ('autonomous', 'organization'): 1,
#  ('organization', 'dao'): 1,
#  ('dao', 'giving'): 1,
#  ('giving', 'away'): 1,
#  ('away', 'two'): 1,
#  ('two', 'seat'): 1,
#  ('seat', 'blue'): 1,
#  ('blue', 'origin'): 1,
#  ('origin', 'flight'): 1,
#  ('flight', 'spacethis'): 1,
#  ('spacethis', 'likely'): 1,
#  ('likely', 'first'): 1,
#  ('first', 'time'): 1,
#  ('time', 'nonfungible'): 1,
#  ('nonfungible', 'token'): 1,
#  ('token', 'nfts'): 1,
#  ('nfts', 'played'): 1,
#  ('played', 'role'): 1,
#  ('role', 'minting'): 1,
#  ('minting', '4509'): 1,
#  ('4509', 'char'): 1,
#  ('char', 'crypto'): 2,
#  ('crypto', 'winter'): 2,
#  ('winter', 'may'): 1,
#  ('may', 'ethereum'): 1,
#  ('ethereum', 'look'): 1,
#  ('look', 'like'): 1,
#  ('like', 'buy'): 1,
#  ('buy', 'winklevoss'): 1,
#  ('winklevoss', 'twin'): 1,
#  ('twin', 'cutting'): 1,
#  ('cutting', 'staff'): 1,
#  ('staff', 'gemini'): 1,
#  ('gemini', 'say'): 1,
#  ('say', 'crypto'): 1,
#  ('winter', 'upon'): 1,
#  ('upon', 'u'): 1,
#  ('u', 'price'): 1,
#  ('price', 'ethereum'): 1,
#  ('ethereum', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'eth'): 1,
#  ('eth', '3614'): 1,
#  ('3614', 'char'): 1,
#  ('char', 'new'): 1,
#  ('new', 'york'): 1,
#  ('york', 'lawmaker'): 1,
#  ('lawmaker', 'passed'): 1,
#  ('passed', 'bill'): 1,
#  ('bill', 'would'): 2,
#  ('would', 'temporarily'): 1,
#  ('temporarily', 'ban'): 1,
#  ('ban', 'new'): 1,
#  ('new', 'bitcoin'): 1,
#  ('bitcoin', 'mining'): 1,
#  ('mining', 'operation'): 2,
#  ('operation', 'early'): 1,
#  ('early', 'friday'): 1,
#  ('friday', 'state'): 1,
#  ('state', 'senator'): 1,
#  ('senator', 'voted'): 1,
#  ('voted', '3627'): 1,
#  ('3627', 'pas'): 1,
#  ('pas', 'legislation'): 1,
#  ('legislation', 'bound'): 1,
#  ('bound', 'desk'): 1,
#  ('desk', '2036'): 1,
#  ('2036', 'char'): 1,
#  ('char', 'davos'): 1,
#  ('davos', 'switzerland'): 1,
#  ('switzerland', 'may'): 1,
#  ('may', '25'): 1,
#  ('25', 'reuters'): 1,
#  ('reuters', 'ethereums'): 1,
#  ('ethereums', 'cofounder'): 1,
#  ('cofounder', 'gavin'): 1,
#  ('gavin', 'wood'): 1,
#  ('wood', 'said'): 1,
#  ('said', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'investor'): 1,
#  ('investor', 'need'): 1,
#  ('need', 'aware'): 1,
#  ('aware', 'backing'): 1,
#  ('backing', 'holding'): 1,
#  ('holding', 'market'): 1,
#  ('market', 'rout'): 1,
#  ('rout', 'wiped'): 1,
#  ('wiped', '1744'): 1,
#  ('1744', 'char'): 1,
#  ('char', 'nvidia'): 1,
#  ('nvidia', 'launched'): 1,
#  ('launched', 'ampere'): 1,
#  ('ampere', 'lite'): 1,
#  ('lite', 'hash'): 1,
#  ('hash', 'rate'): 1,
#  ('rate', 'lhr'): 1,
#  ('lhr', 'graphic'): 1,
#  ('graphic', 'card'): 1,
#  ('card', 'feared'): 1,
#  ('feared', 'ethereum'): 1,
#  ('ethereum', 'antimining'): 1,
#  ('antimining', 'limiter'): 1,
#  ('limiter', 'world'): 1,
#  ('world', 'knew'): 1,
#  ('knew', 'wa'): 1,
#  ('wa', 'matter'): 1,
#  ('matter', 'time'): 1,
#  ('time', 'someone'): 1,
#  ('someone', 'team'): 1,
#  ('team', 'cracked'): 1,
#  ('cracked', 'niceh'): 1,
#  ('niceh', '1230'): 1,
#  ('1230', 'char'): 1,
#  ('crypto', 'roller'): 1,
#  ('roller', 'coaster'): 1,
#  ('coaster', 'ride'): 1,
#  ('ride', 'continues'): 1,
#  ('continues', 'plummet'): 1,
#  ('plummet', 'downhill'): 1,
#  ('downhill', 'fast'): 1,
#  ('fast', 'coinbase'): 1,
#  ('coinbase', 'one'): 1,
#  ('one', 'largest'): 1,
#  ('largest', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'exchange'): 1,
#  ('exchange', 'platform'): 1,
#  ('platform', 'laying'): 1,
#  ('laying', '18'): 1,
#  ('18', 'staff'): 1,
#  ('staff', '1100'): 1,
#  ('1100', 'employee'): 1,
#  ('employee', 'according'): 1,
#  ('according', '2041'): 1,
#  ('2041', 'char'): 1,
#  ('char', 'june'): 2,
#  ('june', '6'): 1,
#  ('6', 'reuters'): 1,
#  ('reuters', 'bitcoin'): 2,
#  ('bitcoin', 'rose'): 1,
#  ('rose', '52'): 1,
#  ('52', '3144176'): 1,
#  ('3144176', '2000'): 1,
#  ('2000', 'gmt'): 1,
#  ('gmt', 'monday'): 2,
#  ('monday', 'adding'): 1,
#  ('adding', '155278'): 1,
#  ('155278', 'previous'): 1,
#  ('previous', 'closethe'): 1,
#  ('closethe', 'world'): 1,
#  ('world', 'biggest'): 2,
#  ('biggest', 'bestknown'): 2,
#  ('bestknown', 'cryptocurrency'): 2,
#  ('cryptocurrency', '348'): 1,
#  ('348', 'year'): 1,
#  ('year', 'high'): 1,
#  ('high', '335'): 1,
#  ('335', 'char'): 1,
#  ('june', '13'): 1,
#  ('13', 'reuters'): 1,
#  ('bitcoin', 'dropped'): 1,
#  ('dropped', '121'): 1,
#  ('121', '23366'): 1,
#  ('23366', '2002'): 1,
#  ('2002', 'gmt'): 1,
#  ('monday', 'losing'): 1,
#  ('losing', '321895'): 1,
#  ('321895', 'previous'): 1,
#  ('previous', 'closebitcoin'): 1,
#  ('closebitcoin', 'world'): 1,
#  ('cryptocurrency', '516'): 1,
#  ('516', '357'): 1,
#  ('357', 'char'): 1,
#  ('char', 'tweet'): 1,
#  ('tweet', 'buterin'): 1,
#  ('buterin', 'shared'): 1,
#  ('shared', 'paper'): 1,
#  ('paper', 'ai'): 1,
#  ('ai', 'theorist'): 1,
#  ('theorist', 'writer'): 1,
#  ('writer', 'eliezer'): 1,
#  ('eliezer', 'yudkowsky'): 1,
#  ('yudkowsky', 'made'): 1,
#  ('made', 'case'): 1,
#  ('case', 'current'): 1,
#  ('current', 'research'): 1,
#  ('research', 'community'): 1,
#  ('community', 'isnt'): 1,
#  ('isnt', 'enough'): 1,
#  ('enough', 'prevent'): 1,
#  ('prevent', 'potential'): 1,
#  ('potential', 'future'): 1,
#  ('future', 'catastrophe'): 1,
#  ('catastrophe', '409'): 1,
#  ('409', 'char'): 1,
#  ('char', 'youtube'): 1,
#  ('youtube', 'criticised'): 1,
#  ('criticised', 'failing'): 1,
#  ('failing', 'tackle'): 1,
#  ('tackle', 'network'): 1,
#  ('network', 'cybercriminals'): 1,
#  ('cybercriminals', 'streaming'): 1,
#  ('streaming', 'fake'): 1,
#  ('fake', 'elon'): 1,
#  ('elon', 'musk'): 1,
#  ('musk', 'video'): 1,
#  ('video', 'scam'): 1,
#  ('scam', 'viewersthe'): 1,
#  ('viewersthe', 'criminal'): 1,
#  ('criminal', 'hijacking'): 1,
#  ('hijacking', 'youtube'): 1,
#  ('youtube', 'account'): 1,
#  ('account', 'using'): 1,
#  ('using', 'video'): 1,
#  ('video', 'p'): 1,
#  ('p', '3851'): 1,
#  ('3851', 'char'): 1,
#  ('char', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'boom'): 2,
#  ('boom', 'past'): 2,
#  ('past', 'year'): 2,
#  ('year', 'ha'): 2,
#  ('ha', 'helped'): 2,
#  ('helped', 'propel'): 2,
#  ('propel', 'newer'): 2,
#  ('newer', 'market'): 2,
#  ('market', 'record'): 2,
#  ('record', 'height'): 2,
#  ('height', 'digital'): 2,
#  ('digital', 'collectible'): 2,
#  ('collectible', 'known'): 2,
#  ('known', 'nftsthe'): 2,
#  ('nftsthe', 'craze'): 2,
#  ('craze', 'ha'): 2,
#  ('ha', 'pushed'): 2,
#  ('pushed', 'total'): 2,
#  ('total', 'nft'): 2,
#  ('nft', 'sale'): 2,
#  ('sale', 'volume'): 2,
#  ('volume', '29'): 2,
#  ('29', 'billion'): 2,
#  ('billion', 'ov'): 2,
#  ('ov', '2866'): 1,
#  ('2866', 'char'): 1,
#  ('char', 'first'): 1,
#  ('first', 'heard'): 1,
#  ('heard', 'potential'): 1,
#  ('potential', 'blockchain'): 1,
#  ('blockchain', 'supply'): 1,
#  ('supply', 'chain'): 1,
#  ('chain', 'several'): 1,
#  ('several', 'year'): 1,
#  ('year', 'ago'): 1,
#  ('ago', 'almost'): 1,
#  ('almost', 'immediately'): 1,
#  ('immediately', 'thrust'): 1,
#  ('thrust', 'cycle'): 1,
#  ('cycle', 'hype'): 1,
#  ('hype', 'hope'): 1,
#  ('hope', 'could'): 1,
#  ('could', 'u'): 1,
#  ('u', 'followed'): 1,
#  ('followed', 'trou'): 1,
#  ('trou', '4785'): 1,
#  ('4785', 'char'): 1,
#  ('char', 'every'): 1,
#  ('every', 'time'): 1,
#  ('time', 'turn'): 1,
#  ('turn', 'around'): 1,
#  ('around', 'seems'): 1,
#  ('seems', 'another'): 1,
#  ('another', 'celebrity'): 1,
#  ('celebrity', 'hawking'): 1,
#  ('hawking', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'nfts'): 1,
#  ('nfts', 'influencer'): 1,
#  ('influencer', 'kim'): 1,
#  ('kim', 'kardashian'): 1,
#  ('kardashian', 'boxer'): 1,
#  ('boxer', 'floyd'): 1,
#  ('floyd', 'mayweather'): 1,
#  ('mayweather', 'former'): 1,
#  ('former', 'nba'): 1,
#  ('nba', 'athlete'): 1,
#  ('athlete', 'paul'): 1,
#  ('paul', 'pierce'): 1,
#  ('pierce', 'promoted'): 1,
#  ('promoted', 'ether'): 1,
#  ('ether', '2773'): 1,
#  ('2773', 'char'): 1,
#  ('char', 'nft'): 1,
#  ('nft', 'marketplace'): 2,
#  ('marketplace', 'becoming'): 1,
#  ('becoming', 'trend'): 1,
#  ('trend', 'every'): 1,
#  ('every', 'one'): 1,
#  ('one', 'ha'): 1,
#  ('ha', 'started'): 1,
#  ('started', 'build'): 1,
#  ('build', 'nft'): 1,
#  ('marketplace', 'however'): 1,
#  ('however', 'people'): 1,
#  ('people', 'require'): 1,
#  ('require', 'marketplace'): 1,
#  ('marketplace', 'could'): 1,
#  ('could', 'launched'): 1,
#  ('launched', 'mark'): 1,
#  ('mark', '5873'): 1,
#  ('5873', 'char'): 1,
#  ('char', 'solana'): 1,
#  ('solana', 'third'): 1,
#  ('third', 'largest'): 1,
#  ('cryptocurrency', 'market'): 1,
#  ('market', 'capitalization'): 1,
#  ('capitalization', 'fell'): 1,
#  ('fell', '10'): 1,
#  ('10', 'wednesday'): 1,
#  ('wednesday', 'following'): 1,
#  ('following', 'report'): 1,
#  ('report', 'blockchain'): 1,
#  ('blockchain', 'network'): 1,
#  ('network', 'suffering'): 1,
#  ('suffering', 'another'): 1,
#  ('another', 'outagethe'): 1,
#  ('outagethe', 'blockchain'): 1,
#  ('blockchain', 'produced'): 1,
#  ('produced', 'new'): 1,
#  ('new', 'block'): 1,
#  ('block', '566'): 1,
#  ('566', 'char'): 1,
#  ('ov', '2830'): 1,
#  ('2830', 'char'): 1,
#  ('char', '6'): 1,
#  ('6', '6'): 1,
#  ('6', 'poster'): 1,
#  ('poster', 'participatingnew'): 1,
#  ('participatingnew', 'york'): 1,
#  ('york', 'state'): 1,
#  ('state', 'legislature'): 1,
#  ('legislature', 'approved'): 1,
#  ('approved', 'bill'): 1,
#  ('would', 'prevent'): 1,
#  ('prevent', 'fossil'): 1,
#  ('fossil', 'fuel'): 1,
#  ('fuel', 'power'): 1,
#  ('power', 'plant'): 1,
#  ('plant', 'revived'): 1,
#  ('revived', 'power'): 1,
#  ('power', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'mining'): 1,
#  ('operation', 'signed'): 1,
#  ('signed', 'gov'): 1,
#  ('gov', '3200'): 1,
#  ('3200', 'char'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_token, 10)
# Out:
# [('char', 20),
#  ('bitcoin', 15),
#  ('new', 8),
#  ('token', 6),
#  ('blockchain', 6),
#  ('digital', 4),
#  ('biggest', 4),
#  ('cryptocurrencies', 4),
#  ('cryptocurrency', 4),
#  ('reuters', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_token, 10)
# Out:
# [('char', 20),
#  ('cryptocurrency', 10),
#  ('ha', 6),
#  ('crypto', 5),
#  ('new', 4),
#  ('ethereum', 4),
#  ('market', 4),
#  ('year', 4),
#  ('nft', 4),
#  ('video', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_token))
plt.title("Bitcoin WC", fontsize = 40, fontweight="bold")
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_token))
plt.title("Ethereum WC", fontsize = 40, fontweight="bold")
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\ldkel\anaconda3\lib\site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.62.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: setuptools in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (58.0.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.20.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: jinja2 in c:\users\ldkel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ldkel\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\ldkel\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ldkel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ldkel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ldkel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ldkel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ldkel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.8)
# Requirement already satisfied: colorama in c:\users\ldkel\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.4)
# 2022-06-16 01:58:19.276511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-06-16 01:58:19.276940: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ldkel\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ldkel\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_content = ' '.join(btc_sent_df['content'])
btc_content
# Out:
# "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars] Rapper and entrepreneur Shawn Carter, better known as Jay-Z, is bringing Bitcoin to the place where he grew up. On Thursday, Jay-Z and former Twitter CEO Jack Dorsey announced the launch of Bitcoin A… [+2920 chars] A new study on bitcoin calls into question whether the digital currency is truly as decentralized and anonymous as its biggest devotees would have you believe. \r\n Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President Faustin-Archange Touadéra wants to rethink his country's economic philosophy\r\nThe Central African Republic's decision to adopt Bitcoin as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges first. Flexa h… [+1428 chars] By Joe TidyCyber reporter \r\nCryptocurrencies have continued to tumble this week with billions wiped from the value of tokens like Bitcoin. The crash is affecting investors worldwide, including the go… [+6815 chars] (CNN)El Salvador has embraced Bitcoin like no other country, with the government purchasing hundreds of coins last year as it announced that the cryptocurrency would become legal tender. \r\nBut as the… [+842 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars] Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars] Celsius has not said what it plans to do next\r\nExhibition And Experience Zones at The Paris NFT Day Conference\r\nThe Celsius Network, a decentralized finance (DeFi) platform and one of the largest cry… [+3737 chars] Photo Illustration by Grayson Blackmon / The Verge; Photo by Oliyarnyk / CC-BY-SA-4.0\r\n\n \n\n\n With Michael Chobanian, the president of the Blockchain Association of Ukraine The terrible, unprovoked wa… [+52103 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world's biggest and best-known cryptocurrency is down 34.8% from the year's high… [+335 chars] June 13 (Reuters) - Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 51.6% from t… [+357 chars] SINGAPORE, June 14 (Reuters) - Bitcoin neared a price level on Tuesday that could force software firm MicroStrategy Inc (MSTR.O) to stake more tokens against a bitcoin-backed loan or trigger selling … [+1873 chars] May 24 (Reuters) - The crypto winter is into its ninth week and bitcoin can't shake the chills.\r\nFrom technicals to turnover, market indicators are flashing red or amber for the biggest cryptocurrenc… [+3967 chars] Terra launched a new blockchain with a new luna token, today. Seth Green's animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the … [+3854 chars] After two linked cryptocurrencies collapsed and became almost worthless, a plan emerged to create a new blockchain for the luna cryptocurrency. Seth Green's NFTs were stolen in a phishing scam. Nike … [+3932 chars] Terra is launching a new blockchain with a new luna token. Seth Green's animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the Mex… [+3792 chars] Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validati ...

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_content)

# Add a title to the document
btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(btc_doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars]
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rapper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and entrepreneur
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shawn Carter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , better known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay-Z
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , is bringing Bitcoin to the place where he grew up. On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay-Z
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and former Twitter CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jack Dorsey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br> Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Faustin-Archange Touadéra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Central African Republic's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  decision to adopt
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# . Flexa h… [+1428 chars] By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe TidyCyber
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Cryptocurrencies have continued to tumble
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     billions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  wiped from the value of tokens like
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . The crash is affecting investors worldwide, including the go… [+6815 chars] (CNN)El
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has embraced Bitcoin like no other country, with the government purchasing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of coins
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>But as the… [+842 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# </br>Exhibition And Experience Zones at
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Paris NFT Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# </br>
# <mark class="entit

# %%
# List all Entities
for ent in btc_doc.ents:
    print("{} {}".format(ent.text, ent.label_))
# Out:
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Rapper NORP
# Shawn Carter PERSON
# Jay-Z PERSON
# Thursday DATE
# Jay-Z PERSON
# Jack Dorsey PERSON
# Faustin-Archange Touadéra LAW
# The Central African Republic's ORG
# Bitcoin NORP
# first ORDINAL
# Joe TidyCyber PERSON
# this week DATE
# billions CARDINAL
# Bitcoin NORP
# Salvador ORG
# hundreds CARDINAL
# last year DATE
# nearly three feet QUANTITY
# The Paris NFT Day EVENT
# The Celsius Network PRODUCT
# DeFi GPE
# ] Photo Illustration WORK_OF_ART
# Grayson Blackmon PERSON
# Oliyarnyk / CC-BY-SA-4.0 ORG
# Michael Chobanian PERSON
# the Blockchain Association of Ukraine ORG
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# Reuters ORG
# 12.1% PERCENT
# 23,366 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 3,218.95 MONEY
# 51.6% PERCENT
# June 14 DATE
# Reuters ORG
# Tuesday DATE
# MicroStrategy Inc ORG
# May 24 DATE
# Reuters ORG
# its ninth week DATE
# today DATE
# Seth Green's PERSON
# NFT ORG
# two CARDINAL
# Seth Green's PERSON
# Nike ORG
# Seth Green's PERSON
# NFT ORG
# Sam Bankman-Fried PERSON
# the digital asset exchange ORG
# FTX ORG
# Riot Blockchain PERSON
# Marathon Digital Holdings ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_content = ' '.join(eth_sent_df['content'])
eth_content
# Out:
# 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] GameStop is going all-in on crypto. The video game retailer launched\xa0its own self-custodial Ethereum digital wallet, it said Monday. The wallet will be accessible through a Google Chrome extension an… [+1491 chars] The ability to conduct external transfers on PayPal\'s crypto platform, an image of which can be seen below, will start rolling out to users today and be available to everyone in the U.S. in the next … [+687 chars] A decentralized autonomous organization, or DAO, is giving away two seats on a Blue Origin flight to space.\r\nThis is likely the first time non-fungible tokens, or NFTs, have played a role in minting … [+4509 chars] Crypto Winter It May Be, But Ethereum Looks Like A Buy \r\nThe Winklevoss twins are cutting the staff at Gemini and say crypto winter is upon us. With the price of Ethereum (Cryptocurrency: ETH) down m… [+3614 chars] New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It\'s now bound for the desk of… [+2036 chars] DAVOS, Switzerland, May 25 (Reuters) - Ethereum\'s co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars] The crypto roller coaster ride continues to plummet downhill fast. Coinbase, one of the largest cryptocurrency exchange platforms, is laying off 18% of its staff, or about 1,100 employees, according … [+2041 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world\'s biggest and best-known cryptocurrency is down 34.8% from the year\'s high… [+335 chars] June 13 (Reuters) - Bitcoin dropped 12.1% to $23,366 at 2002 GMT on Monday, losing $3,218.95 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 51.6% from t… [+357 chars] [In a tweet] Buterin shared a paper by AI theorist and writer Eliezer Yudkowsky that made a case for why the current research community isn\'t doing enough to prevent a potential future catastrophe at… [+409 chars] YouTube is being criticised for failing to tackle a network of cyber-criminals streaming fake Elon Musk videos to scam viewers.\r\nThe criminals are hijacking YouTube accounts and using the videos to p… [+3851 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars] We first heard about the potential of blockchain in supply chains several years ago, and almost immediately were thrust into a cycle of hype and hope of what they could do for us, followed by a "trou… [+4785 chars] Every time you turn around, it seems another celebrity is hawking cryptocurrency or NFTs. Influencer Kim Kardashian, boxer Floyd Mayweather, and former NBA athlete Paul Pierce have all promoted Ether… [+2773 chars] NFT marketplaces are becoming the trend, and each and every one of them has started to build their own NFT marketplaces. \r\nHowever, few people require a marketplace that could be launched in the mark… [+5873 chars] Solana, the third largest cryptocurrency by market capitalization, fell 10% Wednesday following reports of its blockchain network suffering another outage.\xa0\r\nThe blockchain had not produced new block… [+566 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_content)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has officially thrown itself headlong into the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] GameStop is going all-in on crypto. The video game retailer launched its own self-custodial
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  digital wallet, it said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The wallet will be accessible through a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chrome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  extension an… [+1491 chars] The ability to conduct external transfers on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's crypto platform, an image of which can be seen below, will start rolling out to users
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and be available to everyone in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in the next … [+687 chars] A decentralized autonomous organization, or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DAO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is giving away
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  seats on a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blue Origin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>This is likely the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>The Winklevoss twins are cutting the staff at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and say crypto winter is upon us. With the price of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum (Cryptocurrency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : ETH) down m… [
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3614
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars] DAVOS,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switzerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereum's co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gavin Wood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin

# %%
# List all Entities
for ent in eth_doc.ents:
    print("{} {}".format(ent.text, ent.label_))
# Out:
# GameStop ORG
# web3 LOC
# Ethereum ORG
# Monday DATE
# Google Chrome PRODUCT
# PayPal ORG
# today DATE
# U.S. GPE
# DAO ORG
# two CARDINAL
# Blue Origin ORG
# first ORDINAL
# Gemini ORG
# Ethereum (Cryptocurrency ORG
# +3614 NORP
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Switzerland GPE
# May 25 DATE
# Reuters ORG
# Gavin Wood PERSON
# Nvidia PERSON
# Ampere Lite Hash Rate WORK_OF_ART
# LHR ORG
# Ethereum ORG
# 18% PERCENT
# about 1,100 CARDINAL
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# Reuters ORG
# 12.1% PERCENT
# 23,366 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 3,218.95 MONEY
# 51.6% PERCENT
# Buterin PERSON
# AI ORG
# Eliezer Yudkowsky PERSON
# YouTube ORG
# Elon Musk PERSON
# YouTube ORG
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# several years ago DATE
# Kim Kardashian PERSON
# Floyd Mayweather PERSON
# NBA ORG
# Paul Pierce PERSON
# Ether PERSON
# NFT ORG
# NFT ORG
# Solana PERSON
# third ORDINAL
# 10% PERCENT
# Wednesday DATE
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# 6 CARDINAL
# 6 CARDINAL
# New York's GPE

# %% [markdown]
# ---
